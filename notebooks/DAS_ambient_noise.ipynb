# %% [markdown]
# # 0. Import packages and set up correct path

# %%
# on Docker/local
import sys
sys.path.append("../src")
sys.path.append("../DASstore") 
sys.path.append("/home/jmanos/notebooks/whidbey_noise")

import os
import time
from datetime import datetime, timedelta

import h5py
import numpy as np
import DAS_module
import matplotlib.pyplot as plt
from tqdm import tqdm
import dasquakes
from dasquakes import das_downloader

import importlib
importlib.reload(dasquakes)
# Out:
# <module 'dasquakes' from '../src/dasquakes.py'>

# %% [markdown]
# # 1. Get data that we want

# %%
cab = 'whidbey'
this_id = None
event_df = None
t0 = datetime(2022, 12, 24, 4, 55,0)
record_length = 5


data, times, attrs, x_max, this_id, data_filt, t0 = das_downloader(event_df, this_id, cab, t0 = t0, record_length = record_length)
# Out:
# /data/data6/whidbey/whidbey_2022-12-24_04-55*.h5
# /data/data6/whidbey/whidbey_2022-12-24_04-56*.h5
# /data/data6/whidbey/whidbey_2022-12-24_04-57*.h5
# /data/data6/whidbey/whidbey_2022-12-24_04-58*.h5
# /data/data6/whidbey/whidbey_2022-12-24_04-59*.h5

# %% [markdown]
# # 1.1 Slice the data how want to just choose specific channels

# %%
# start and end channel index for the sub-array
# cha1, cha2 = 0, attrs[ 'NumberOfLoci'] #all channels
cha1, cha2 = 1200, 1650 #all channels
cha_spacing = attrs['SpatialSamplingInterval']

# %% [markdown]
# # 1.2 Plot the results

# %%
plt.figure(figsize = (10, 5), dpi = 100)
plt.imshow(data[:,cha1:cha2].T, aspect = 'auto', 
           cmap = 'RdBu', vmax = 1.5, vmin = -1.5, origin='lower')
_ =plt.yticks(np.linspace(cha1, cha2, 4) - cha1, 
              [int(i) for i in np.linspace(cha1, cha2, 4)], fontsize = 12)
plt.ylabel("Channel number", fontsize = 15)
plt.xlabel("Time", fontsize = 15)
twiny = plt.gca().twinx()
twiny.set_yticks(np.linspace(0, cha2 - cha1, 4), 
                             [int(i* cha_spacing) for i in np.linspace(cha1, cha2, 4)])
twiny.set_ylabel("Distance along cable (m)", fontsize = 15)
plt.colorbar(pad = 0.1)
# Out:
# /home/jmanos/miniconda3/envs/comcat/lib/python3.7/site-packages/ipykernel_launcher.py:12: MatplotlibDeprecationWarning: Starting from Matplotlib 3.6, colorbar() will steal space from the mappable's axes, rather than from the current axes, to place the colorbar.  To silence this warning, explicitly pass the 'ax' argument to colorbar().
#   if sys.path[0] == "":

# %% [markdown]
# # 2. Pre-processing

# %% [markdown]
# # 2.1 define parameters

# %%
sps       = attrs['PulseRate']  # current sampling rate
samp_freq = 50                  # targeted sampling rate
freqmin   = 1                   # pre filtering frequency bandwidth
freqmax   = 20                  # note this cannot exceed Nquist freq

freq_norm   = 'rma'             # 'no' for no whitening, or 'rma' for running-mean average, 'phase_only' for sign-bit normalization in freq domain.
time_norm   = 'one_bit'         # 'no' for no normalization, or 'rma', 'one_bit' for normalization in time domain
cc_method   = 'xcorr'           # 'xcorr' for pure cross correlation, 'deconv' for deconvolution; FOR "COHERENCY" PLEASE set freq_norm to "rma", time_norm to "no" and cc_method to "xcorr"
smooth_N    = 100               # moving window length for time domain normalization if selected (points)
smoothspect_N  = 100            # moving window length to smooth spectrum amplitude (points)
maxlag      = 8                 # lags of cross-correlation to save (sec)

# criteria for data selection
max_over_std = 10               # threahold to remove window of bad signals: set it to 10*9 if prefer not to remove them

cc_len = 60*record_length       # correlate length in second
step   = 60                     # stepping length in second

cha_list = np.array(range(cha1, cha2)) 
nsta = len(cha_list)
n_pair = int((nsta+1)*nsta/2)
n_lag = maxlag * samp_freq * 2 + 1

prepro_para = {'freqmin':freqmin,
               'freqmax':freqmax,
               'sps':sps,
               'npts_chunk':cc_len*sps,
               'nsta':nsta,
               'cha_list':cha_list,
               'samp_freq':samp_freq,
               'freq_norm':freq_norm,
               'time_norm':time_norm,
               'cc_method':cc_method,
               'smooth_N':smooth_N,
               'smoothspect_N':smoothspect_N,
               'maxlag':maxlag,
               'max_over_std':max_over_std}

# # you can save this parameter file to local
# metadata = os.path.join(CCFDIR, 'prepro_fft_info.txt')
# # output parameter info
# fout = open(metadata,'w')
# fout.write(str(prepro_para));fout.close()

# %%
trace_stdS, dataS = DAS_module.preprocess_raw_make_stat(data[:,cha1:cha2], prepro_para)

# %%
plt.figure(figsize = (10, 5), dpi = 100)
plt.imshow(dataS, aspect = 'auto', 
           cmap = 'RdBu', vmax = .001, vmin = -.001, origin='lower')
_ =plt.yticks(np.linspace(cha1, cha2, 4) - cha1, 
              [int(i) for i in np.linspace(cha1, cha2, 4)], fontsize = 12)
plt.ylabel("Channel number", fontsize = 15)
plt.xlabel("Time", fontsize = 15)
twiny = plt.gca().twinx()
twiny.set_yticks(np.linspace(0, cha2 - cha1, 4), 
                             [int(i* cha_spacing) for i in np.linspace(cha1, cha2, 4)])
twiny.set_ylabel("Distance along cable (m)", fontsize = 15)
plt.colorbar(pad = 0.1)
# Out:
# /home/jmanos/miniconda3/envs/comcat/lib/python3.7/site-packages/ipykernel_launcher.py:12: MatplotlibDeprecationWarning: Starting from Matplotlib 3.6, colorbar() will steal space from the mappable's axes, rather than from the current axes, to place the colorbar.  To silence this warning, explicitly pass the 'ax' argument to colorbar().
#   if sys.path[0] == "":

# %% [markdown]
# # 2.1 FFT, temporal and frequency normalization

# %%
white_spect = DAS_module.noise_processing(dataS, prepro_para)
Nfft = white_spect.shape[1]; Nfft2 = Nfft // 2
data = white_spect[:, :Nfft2]
del dataS, white_spect

print(data.shape, data.dtype)
# Out:
# (450, 7500) complex64

# %% [markdown]
# # 2.2 Channel-pair selection

# %%
ind = np.where((trace_stdS < prepro_para['max_over_std']) &
                        (trace_stdS > 0) &
                (np.isnan(trace_stdS) == 0))[0]
if not len(ind):
    raise ValueError('the max_over_std criteria is too high which results in no data')
sta = cha_list[ind]
white_spect = data[ind]

print(white_spect.shape, white_spect.dtype)
# Out:
# (153, 7500) complex64

# %% [markdown]
# # 2.3 Cross-correlation over all channel pairs

# %%
# loop over all stations
for iiS in range(len(sta)):
    # smooth the source spectrum
    sfft1 = DAS_module.smooth_source_spect(white_spect[iiS], prepro_para)

    # correlate one source with all receivers
    corr, tindx = DAS_module.correlate(sfft1, white_spect[iiS:], prepro_para, Nfft)
    
    print(f"source channel index: {sta[iiS]}, correlation shape: {corr.shape}")
# Out:
# source channel index: 1202, correlation shape: (153, 801)
# source channel index: 1203, correlation shape: (152, 801)
# source channel index: 1204, correlation shape: (151, 801)
# source channel index: 1205, correlation shape: (150, 801)
# source channel index: 1207, correlation shape: (149, 801)
# source channel index: 1220, correlation shape: (148, 801)
# source channel index: 1221, correlation shape: (147, 801)
# source channel index: 1225, correlation shape: (146, 801)
# source channel index: 1226, correlation shape: (145, 801)
# source channel index: 1245, correlation shape: (144, 801)
# source channel index: 1257, correlation shape: (143, 801)
# source channel index: 1258, correlation shape: (142, 801)
# source channel index: 1259, correlation shape: (141, 801)
# source channel index: 1260, correlation shape: (140, 801)
# source channel index: 1264, correlation shape: (139, 801)
# source channel index: 1266, correlation shape: (138, 801)
# source channel index: 1267, correlation shape: (137, 801)
# source channel index: 1277, correlation shape: (136, 801)
# source channel index: 1278, correlation shape: (135, 801)
# source channel index: 1279, correlation shape: (134, 801)
# source channel index: 1280, correlation shape: (133, 801)
# source channel index: 1281, correlation shape: (132, 801)
# source channel index: 1287, correlation shape: (131, 801)
# source channel index: 1288, correlation shape: (130, 801)
# source channel index: 1289, correlation shape: (129, 801)
# source channel index: 1303, correlation shape: (128, 801)
# source channel index: 1334, correlation shape: (127, 801)
# source channel index: 1345, correlation shape: (126, 801)
# source channel index: 1352, correlation shape: (125, 801)
# source channel index: 1357, correlation shape: (124, 801)
# source channel index: 1358, correlation shape: (123, 801)
# source channel index: 1359, correlation shape: (122, 801)
# source channel index: 1360, correlation shape: (121, 801)
# source channel index: 1361, correlation shape: (120, 801)
# source channel index: 1362, correlation shape: (119, 801)
# source channel index: 1363, correlation shape: (118, 801)
# source channel index: 1364, correlation shape: (117, 801)
# source channel index: 1365, correlation shape: (116, 801)
# source channel index: 1374, correlation shape: (115, 801)
# source channel index: 1377, correlation shape: (114, 801)
# source channel index: 1390, correlation shape: (113, 801)
# source channel index: 1391, correlation shape: (112, 801)
# source channel index: 1392, correlation shape: (111, 801)
# source channel index: 1393, correlation shape: (110, 801)
# source channel index: 1404, correlation shape: (109, 801)
# source channel index: 1407, correlation shape: (108, 801)
# source channel index: 1408, correlation shape: (107, 801)
# source channel index: 1410, correlation shape: (106, 801)
# source channel index: 1412, correlation shape: (105, 801)
# source channel index: 1415, correlation shape: (104, 801)
# source channel index: 1416, correlation shape: (103, 801)
# source channel index: 1417, correlation shape: (102, 801)
# source channel index: 1418, correlation shape: (101, 801)
# source channel index: 1423, correlation shape: (100, 801)
# source channel index: 1424, correlation shape: (99, 801)
# source channel index: 1425, correlation shape: (98, 801)
# source channel index: 1426, correlation shape: (97, 801)
# source channel index: 1433, correlation shape: (96, 801)
# source channel index: 1435, correlation shape: (95, 801)
# source channel index: 1436, correlation shape: (94, 801)
# source channel index: 1437, correlation shape: (93, 801)
# source channel index: 1438, correlation shape: (92, 801)
# source channel index: 1439, correlation shape: (91, 801)
# source channel index: 1457, correlation shape: (90, 801)
# source channel index: 1467, correlation shape: (89, 801)
# source channel index: 1468, correlation shape: (88, 801)
# source channel index: 1469, correlation shape: (87, 801)
# source channel index: 1470, correlation shape: (86, 801)
# source channel index: 1471, correlation shape: (85, 801)
# source channel index: 1472, correlation shape: (84, 801)
# source channel index: 1473, correlation shape: (83, 801)
# source channel index: 1475, correlation shape: (82, 801)
# source channel index: 1476, correlation shape: (81, 801)
# source channel index: 1477, correlation shape: (80, 801)
# source channel index: 1478, correlation shape: (79, 801)
# source channel index: 1479, correlation shape: (78, 801)
# source channel index: 1480, correlation shape: (77, 801)
# source channel index: 1481, correlation shape: (76, 801)
# source channel index: 1482, correlation shape: (75, 801)
# source channel index: 1483, correlation shape: (74, 801)
# source channel index: 1484, correlation shape: (73, 801)
# source channel index: 1485, correlation shape: (72, 801)
# source channel index: 1486, correlation shape: (71, 801)
# source channel index: 1488, correlation shape: (70, 801)
# source channel index: 1489, correlation shape: (69, 801)
# source channel index: 1490, correlation shape: (68, 801)
# source channel index: 1491, correlation shape: (67, 801)
# source channel index: 1492, correlation shape: (66, 801)
# source channel index: 1493, correlation shape: (65, 801)
# source channel index: 1499, correlation shape: (64, 801)
# source channel index: 1500, correlation shape: (63, 801)
# source channel index: 1501, correlation shape: (62, 801)
# source channel index: 1507, correlation shape: (61, 801)
# source channel index: 1508, correlation shape: (60, 801)
# source channel index: 1509, correlation shape: (59, 801)
# source channel index: 1510, correlation shape: (58, 801)
# source channel index: 1511, correlation shape: (57, 801)
# source channel index: 1512, correlation shape: (56, 801)
# source channel index: 1513, correlation shape: (55, 801)
# source channel index: 1520, correlation shape: (54, 801)
# source channel index: 1522, correlation shape: (53, 801)
# source channel index: 1523, correlation shape: (52, 801)
# source channel index: 1524, correlation shape: (51, 801)
# source channel index: 1525, correlation shape: (50, 801)
# source channel index: 1528, correlation shape: (49, 801)
# source channel index: 1529, correlation shape: (48, 801)
# source channel index: 1530, correlation shape: (47, 801)
# source channel index: 1533, correlation shape: (46, 801)
# source channel index: 1534, correlation shape: (45, 801)
# source channel index: 1539, correlation shape: (44, 801)
# source channel index: 1540, correlation shape: (43, 801)
# source channel index: 1541, correlation shape: (42, 801)
# source channel index: 1542, correlation shape: (41, 801)
# source channel index: 1543, correlation shape: (40, 801)
# source channel index: 1544, correlation shape: (39, 801)
# source channel index: 1545, correlation shape: (38, 801)
# source channel index: 1557, correlation shape: (37, 801)
# source channel index: 1559, correlation shape: (36, 801)
# source channel index: 1560, correlation shape: (35, 801)
# source channel index: 1561, correlation shape: (34, 801)
# source channel index: 1562, correlation shape: (33, 801)
# source channel index: 1563, correlation shape: (32, 801)
# source channel index: 1585, correlation shape: (31, 801)
# source channel index: 1587, correlation shape: (30, 801)
# source channel index: 1592, correlation shape: (29, 801)
# source channel index: 1595, correlation shape: (28, 801)
# source channel index: 1598, correlation shape: (27, 801)
# source channel index: 1600, correlation shape: (26, 801)
# source channel index: 1601, correlation shape: (25, 801)
# source channel index: 1602, correlation shape: (24, 801)
# source channel index: 1603, correlation shape: (23, 801)
# source channel index: 1607, correlation shape: (22, 801)
# source channel index: 1608, correlation shape: (21, 801)
# source channel index: 1609, correlation shape: (20, 801)
# source channel index: 1610, correlation shape: (19, 801)
# source channel index: 1611, correlation shape: (18, 801)
# source channel index: 1612, correlation shape: (17, 801)
# source channel index: 1613, correlation shape: (16, 801)
# source channel index: 1614, correlation shape: (15, 801)
# source channel index: 1615, correlation shape: (14, 801)
# source channel index: 1617, correlation shape: (13, 801)
# source channel index: 1618, correlation shape: (12, 801)
# source channel index: 1619, correlation shape: (11, 801)
# source channel index: 1620, correlation shape: (10, 801)
# source channel index: 1621, correlation shape: (9, 801)
# source channel index: 1622, correlation shape: (8, 801)
# source channel index: 1623, correlation shape: (7, 801)
# source channel index: 1624, correlation shape: (6, 801)
# source channel index: 1629, correlation shape: (5, 801)
# source channel index: 1630, correlation shape: (4, 801)
# source channel index: 1633, correlation shape: (3, 801)
# source channel index: 1636, correlation shape: (2, 801)
# source channel index: 1649, correlation shape: (1, 801)

# %% [markdown]
# # 3 10-minute linear stacking
# We create this `corr_full` and `stack_full` matrix to store a sub-stacking results. More specifically, we linearly stack each minute of correlation in memory, and only save the hourly stacking to the CCF storage (local ASDF, S3, etc.)

# %%
corr_full = np.zeros([n_lag, n_pair], dtype = np.float32)
stack_full = np.zeros([1, n_pair], dtype = np.int32)
task_t0 = datetime(2022, 12, 24, 4, 49, 0)

n_minute = 6
record_length = 120

# %% [markdown]
# We loop over all data chunk. Reminder that the data is on the cloud, and computing is made on this server. So we are downloading the data as we compute at the same time (async option?)

# %% [markdown]
# # 3.1 Cross-correlation

# %%
sps       = attrs['PulseRate']  # current sampling rate
samp_freq = 50                  # targeted sampling rate
freqmin   = 1                   # pre filtering frequency bandwidth
freqmax   = 20                  # note this cannot exceed Nquist freq

freq_norm   = 'rma'             # 'no' for no whitening, or 'rma' for running-mean average, 'phase_only' for sign-bit normalization in freq domain.
time_norm   = 'one_bit'         # 'no' for no normalization, or 'rma', 'one_bit' for normalization in time domain
cc_method   = 'xcorr'           # 'xcorr' for pure cross correlation, 'deconv' for deconvolution; FOR "COHERENCY" PLEASE set freq_norm to "rma", time_norm to "no" and cc_method to "xcorr"
smooth_N    = 100               # moving window length for time domain normalization if selected (points)
smoothspect_N  = 100            # moving window length to smooth spectrum amplitude (points)
maxlag      = 8                 # lags of cross-correlation to save (sec)

# criteria for data selection
max_over_std = 10               # threahold to remove window of bad signals: set it to 10*9 if prefer not to remove them

cc_len = 60*record_length       # correlate length in second
step   = 60                     # stepping length in second

cha_list = np.array(range(cha1, cha2)) 
nsta = len(cha_list)
n_pair = int((nsta+1)*nsta/2)
n_lag = maxlag * samp_freq * 2 + 1

prepro_para = {'freqmin':freqmin,
               'freqmax':freqmax,
               'sps':sps,
               'npts_chunk':cc_len*sps,
               'nsta':nsta,
               'cha_list':cha_list,
               'samp_freq':samp_freq,
               'freq_norm':freq_norm,
               'time_norm':time_norm,
               'cc_method':cc_method,
               'smooth_N':smooth_N,
               'smoothspect_N':smoothspect_N,
               'maxlag':maxlag,
               'max_over_std':max_over_std}

# # you can save this parameter file to local
# metadata = os.path.join(CCFDIR, 'prepro_fft_info.txt')
# # output parameter info
# fout = open(metadata,'w')
# fout.write(str(prepro_para));fout.close()

# %%
# each task is one minute
pbar = tqdm(range(n_minute))
t_query = 0; t_compute = 0
for imin in pbar:
    t0 = time.time()
    pbar.set_description(f"Processing {task_t0}")
    task_t0 += timedelta(minutes = record_length)
    tdata, times, attrs, x_max, this_id, data_filt, t_dummy = das_downloader(None, 
                                                                       None, 
                                                                       cab, 
                                                                       t0 = task_t0, 
                                                                       record_length = record_length)
    
    
#     tdata = client.get_data(cha_list, 
#             starttime = task_t0,
#             endtime = task_t0 + timedelta(minutes = 1)).T
    t_query += time.time() - t0

    t1 = time.time()
    # perform pre-processing
    trace_stdS, dataS = DAS_module.preprocess_raw_make_stat(tdata[:,cha1:cha2], prepro_para)
    # do normalization if needed
    white_spect = DAS_module.noise_processing(dataS, prepro_para)
    Nfft = white_spect.shape[1]; Nfft2 = Nfft // 2
    data = white_spect[:, :Nfft2]
    del dataS, white_spect

    ind = np.where((trace_stdS < prepro_para['max_over_std']) &
                            (trace_stdS > 0) &
                    (np.isnan(trace_stdS) == 0))[0]
    if not len(ind):
        raise ValueError('the max_over_std criteria is too high which results in no data')
    sta = cha_list[ind]
    white_spect = data[ind]

    # loop over all stations
    for iiS in range(len(sta)):
        # smooth the source spectrum
        sfft1 = DAS_module.smooth_source_spect(white_spect[iiS], prepro_para)
        
        # correlate one source with all receivers
        corr, tindx = DAS_module.correlate(sfft1, white_spect[iiS:], prepro_para, Nfft)

        # update the receiver list
        tsta = sta[iiS:]
        receiver_lst = tsta[tindx]

        iS = int((cha2*2 - cha1 - sta[iiS] + 1) * (sta[iiS] - cha1) / 2)

        # stacking one minute
        corr_full[:, iS + receiver_lst - sta[iiS]] += corr.T
        stack_full[:, iS + receiver_lst - sta[iiS]] += 1
        
    t_compute += time.time() - t1
corr_full /= stack_full
print("%.3f seconds in data query, %.3f seconds in xcorr computing" % (t_query, t_compute))
# Out:
# Processing 2022-12-24 04:49:00:   0%|          | 0/6 [00:00<?, ?it/s]
# /data/data6/whidbey/whidbey_2022-12-24_06-49*.h5
# /data/data6/whidbey/whidbey_2022-12-24_06-50*.h5
# /data/data6/whidbey/whidbey_2022-12-24_06-51*.h5
# /data/data6/whidbey/whidbey_2022-12-24_06-52*.h5
# /data/data6/whidbey/whidbey_2022-12-24_06-53*.h5
# /data/data6/whidbey/whidbey_2022-12-24_06-54*.h5
# /data/data6/whidbey/whidbey_2022-12-24_06-55*.h5
# /data/data6/whidbey/whidbey_2022-12-24_06-56*.h5
# /data/data6/whidbey/whidbey_2022-12-24_06-57*.h5
# /data/data6/whidbey/whidbey_2022-12-24_06-58*.h5
# /data/data6/whidbey/whidbey_2022-12-24_06-59*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-00*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-01*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-02*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-03*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-04*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-05*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-06*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-07*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-08*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-09*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-10*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-11*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-12*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-13*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-14*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-15*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-16*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-17*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-18*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-19*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-20*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-21*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-22*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-23*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-24*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-25*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-26*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-27*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-28*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-29*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-30*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-31*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-32*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-33*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-34*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-35*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-36*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-37*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-38*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-39*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-40*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-41*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-42*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-43*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-44*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-45*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-46*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-47*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-48*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-49*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-50*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-51*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-52*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-53*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-54*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-55*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-56*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-57*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-58*.h5
# /data/data6/whidbey/whidbey_2022-12-24_07-59*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-00*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-01*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-02*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-03*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-04*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-05*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-06*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-07*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-08*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-09*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-10*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-11*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-12*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-13*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-14*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-15*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-16*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-17*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-18*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-19*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-20*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-21*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-22*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-23*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-24*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-25*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-26*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-27*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-28*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-29*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-30*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-31*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-32*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-33*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-34*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-35*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-36*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-37*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-38*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-39*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-40*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-41*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-42*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-43*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-44*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-45*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-46*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-47*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-48*.h5
# Processing 2022-12-24 06:49:00:  17%|█▋        | 1/6 [10:04<50:22, 604.60s/it]
# /data/data6/whidbey/whidbey_2022-12-24_08-49*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-50*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-51*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-52*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-53*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-54*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-55*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-56*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-57*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-58*.h5
# /data/data6/whidbey/whidbey_2022-12-24_08-59*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-00*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-01*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-02*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-03*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-04*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-05*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-06*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-07*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-08*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-09*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-10*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-11*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-12*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-13*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-14*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-15*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-16*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-17*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-18*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-19*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-20*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-21*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-22*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-23*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-24*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-25*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-26*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-27*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-28*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-29*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-30*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-31*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-32*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-33*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-34*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-35*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-36*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-37*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-38*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-39*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-40*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-41*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-42*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-43*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-44*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-45*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-46*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-47*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-48*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-49*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-50*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-51*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-52*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-53*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-54*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-55*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-56*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-57*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-58*.h5
# /data/data6/whidbey/whidbey_2022-12-24_09-59*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-00*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-01*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-02*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-03*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-04*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-05*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-06*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-07*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-08*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-09*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-10*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-11*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-12*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-13*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-14*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-15*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-16*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-17*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-18*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-19*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-20*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-21*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-22*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-23*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-24*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-25*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-26*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-27*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-28*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-29*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-30*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-31*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-32*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-33*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-34*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-35*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-36*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-37*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-38*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-39*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-40*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-41*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-42*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-43*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-44*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-45*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-46*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-47*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-48*.h5
# Processing 2022-12-24 08:49:00:  33%|███▎      | 2/6 [22:07<44:55, 673.97s/it]
# /data/data6/whidbey/whidbey_2022-12-24_10-49*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-50*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-51*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-52*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-53*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-54*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-55*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-56*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-57*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-58*.h5
# /data/data6/whidbey/whidbey_2022-12-24_10-59*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-00*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-01*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-02*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-03*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-04*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-05*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-06*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-07*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-08*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-09*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-10*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-11*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-12*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-13*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-14*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-15*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-16*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-17*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-18*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-19*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-20*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-21*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-22*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-23*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-24*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-25*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-26*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-27*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-28*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-29*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-30*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-31*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-32*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-33*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-34*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-35*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-36*.h5
# /data/data6/whidbey/whidbey_2022-12-24_11-37*.h5

# %%
chan_source=2

# %%
plt.figure(figsize = (12, 5), dpi = 100)

plt.imshow(corr_full[:,chan_source*(cha2 - cha1):(chan_source+1)*(cha2 - cha1)].T, aspect = 'auto', cmap = 'RdBu', 
           vmax = 5e-3, vmin = -5e-3, origin = 'lower')

_ =plt.yticks(np.linspace(cha1, cha2, 4) - cha1, 
              [int(i) for i in np.linspace(cha1, cha2, 4)], fontsize = 12)
_ = plt.xticks(np.arange(0, 801, 200), (np.arange(0, 801, 200) - 400)/50, fontsize = 12)
plt.ylabel("Channel number", fontsize = 16)
plt.xlabel("Time lag (sec)", fontsize = 16)
plt.title("source 500", fontsize = 16)
bar = plt.colorbar(pad = 0.1, format = lambda x, pos: '{:.1f}'.format(x*100))
bar.set_label('Cross-correlation Coefficient ($\\times10^{-2}$)', fontsize = 15)

twiny = plt.gca().twinx()
twiny.set_yticks(np.linspace(0, cha2 - cha1, 4), 
                             [int(i* cha_spacing) for i in np.linspace(cha1, cha2, 4)])
twiny.set_ylabel("Distance along cable (m)", fontsize = 15)
# Out:
# Text(0, 0.5, 'Distance along cable (m)')
